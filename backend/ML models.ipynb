# %%
import pandas as pd

# Read the CSV file into a DataFrame
df = pd.read_csv("DSE3101_HDB_Resale_Price/backend/data_merged.csv")

# %%
df = df.drop(df.columns[0], axis=1)
df
# Out:
#         year  month        town  flat_type block       street_name  \
# 0       1990      1  ANG MO KIO     3 ROOM   216  ANG MO KIO AVE 1
# 1       1990      1  ANG MO KIO     3 ROOM   211  ANG MO KIO AVE 3
# 2       1990      1  ANG MO KIO     3 ROOM   202  ANG MO KIO AVE 3
# 3       1990      1  ANG MO KIO     3 ROOM   235  ANG MO KIO AVE 3
# 4       1990      1  ANG MO KIO     3 ROOM   235  ANG MO KIO AVE 3
# ...      ...    ...         ...        ...   ...               ...
# 910092  2024      3      YISHUN  EXECUTIVE   791      YISHUN AVE 2
# 910093  2024      3      YISHUN  EXECUTIVE   392      YISHUN AVE 6
# 910094  2024      3      YISHUN  EXECUTIVE   326    YISHUN RING RD
# 910095  2024      3      YISHUN  EXECUTIVE   360    YISHUN RING RD
# 910096  2024      3      YISHUN  EXECUTIVE   606      YISHUN ST 61
#
#        storey_range  floor_area_sqm      flat_model lease_commence_date  ...  \
# 0          04 TO 06            73.0  NEW GENERATION          1976-01-01  ...
# ...

# %%
# init setup
from pycaret.regression import *
clf1 = setup(data = df,  target = 'resale_price')

# compare models
best = compare_models()
# Out:
# <style type="text/css">
# #T_f8465_row9_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_f8465">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f8465_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_f8465_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f8465_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_f8465_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_f8465_row0_col1" class="data row0 col1" >6731</td>
#     </tr>
#     <tr>
#       <th id="T_f8465_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_f8465_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_f8465_row1_col1" class="data row1 col1" >resale_price</td>
#     </tr>
#     <tr>
#       <th id="T_f8465_level0_row2" class="row_heading level0 row2" >2</th>
# ...
